# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('nba_team_stats_shot_zones.csv')

# Display the first few rows of the DataFrame to confirm it loaded correctly
df.head()
# Out:
#                 Team  RA_FGM  RA_FGA  RA_FG%  NRA_FGM  NRA_FGA  NRA_FG%  \
# 0      Atlanta Hawks    19.3    29.9    64.6      8.4     20.0     41.8
# 1     Boston Celtics    15.0    21.1    71.0      5.8     13.1     44.7
# 2      Brooklyn Nets    14.8    24.4    60.5      5.7     14.5     39.2
# 3  Charlotte Hornets    15.1    24.6    61.6      5.6     14.6     38.0
# 4      Chicago Bulls    17.6    28.3    62.1      6.2     12.2     50.9
#
#    MR_FGM  MR_FGA  MR_FG%  ...  LC3_FG%  RC3_FGM  RC3_FGA  RC3_FG%  C3_FGM  \
# 0     2.2     5.5    40.9  ...     38.6      2.6      6.1     42.6     4.4
# 1     2.7     6.7    39.5  ...     38.4      1.9      4.6     42.2     4.2
# 2     2.9     5.9    48.9  ...     32.5      2.1      5.7     36.6     3.8
# 3     3.2     8.7    37.2  ...     37.5      1.6      4.5     35.9     3.5
# 4     2.7     7.3    37.3  ...     43.1      1.7      5.2     33.1     4.5
#
#    C3_FGA  C3_FG%  AB3_FGM  AB3_FGA  AB3_FG%
# 0    10.8    40.8      8.5     25.2     33.7
# 1    10.4    40.1     14.3     40.2     35.6
# 2    11.0    34.7     10.9     28.2     38.5
# 3     9.5    36.7     11.0     32.3     33.9
# 4    11.5    38.6     11.9     32.4     36.8
#
# [5 rows x 22 columns]

# %%
# Load the CSV files into DataFrames
df1 = pd.read_csv('nba_team_stats_shot_zones.csv')
df2 = pd.read_csv('nba_team_stats_24_25_010525.csv')

# Perform the join on the 'Team' column
merged_df = pd.merge(df1, df2, on='Team', how='inner')  # You can adjust the 'how' parameter as needed

# Display the first few rows of the merged DataFrame
merged_df.head(5)
# Out:
#                 Team  RA_FGM  RA_FGA  RA_FG%  NRA_FGM  NRA_FGA  NRA_FG%  \
# 0      Atlanta Hawks    19.3    29.9    64.6      8.4     20.0     41.8
# 1     Boston Celtics    15.0    21.1    71.0      5.8     13.1     44.7
# 2      Brooklyn Nets    14.8    24.4    60.5      5.7     14.5     39.2
# 3  Charlotte Hornets    15.1    24.6    61.6      5.6     14.6     38.0
# 4      Chicago Bulls    17.6    28.3    62.1      6.2     12.2     50.9
#
#    MR_FGM  MR_FGA  MR_FG%  ...    FT%   ORB   DRB   TRB   AST  STL  BLK   TOV  \
# 0     2.2     5.5    40.9  ...  0.774  12.7  33.6  46.3  29.6  9.8  5.3  15.9
# 1     2.7     6.7    39.5  ...  0.796  10.6  34.2  44.8  26.0  7.5  5.5  12.1
# 2     2.9     5.9    48.9  ...  0.806   8.4  29.6  38.0  25.9  7.2  3.8  15.0
# 3     3.2     8.7    37.2  ...  0.775  13.0  32.2  45.2  23.2  7.9  5.0  16.4
# 4     2.7     7.3    37.3  ...  0.797   8.9  35.4  44.3  29.4  7.5  5.0  15.3
#
#      PF    PTS
# 0  19.0  116.2
# 1  16.4  119.9
# 2  22.5  110.1
# 3  21.4  106.7
# 4  18.6  118.9
#
# [5 rows x 46 columns]

# %%
# Select specific columns
selected_columns = ['Team','RA_FGM', 'RA_FGA', 'RA_FG%',
                    'NRA_FGM', 'NRA_FGA', 'NRA_FG%',
                    'MR_FGM', 'MR_FGA', 'MR_FG%',
                    'LC3_FGM', 'LC3_FGA', 'LC3_FG%',
                    'RC3_FGM', 'RC3_FGA', 'RC3_FG%',
                    'AB3_FGM', 'AB3_FGA', 'AB3_FG%',]

# Create a new DataFrame with only the selected columns
shot_zone_focused_df = df[selected_columns]

# Display the first few rows of the new DataFrame
shot_zone_focused_df.head(5)
# Out:
#                 Team  RA_FGM  RA_FGA  RA_FG%  NRA_FGM  NRA_FGA  NRA_FG%  \
# 0      Atlanta Hawks    19.3    29.9    64.6      8.4     20.0     41.8
# 1     Boston Celtics    15.0    21.1    71.0      5.8     13.1     44.7
# 2      Brooklyn Nets    14.8    24.4    60.5      5.7     14.5     39.2
# 3  Charlotte Hornets    15.1    24.6    61.6      5.6     14.6     38.0
# 4      Chicago Bulls    17.6    28.3    62.1      6.2     12.2     50.9
#
#    MR_FGM  MR_FGA  MR_FG%  LC3_FGM  LC3_FGA  LC3_FG%  RC3_FGM  RC3_FGA  \
# 0     2.2     5.5    40.9      1.8      4.6     38.6      2.6      6.1
# 1     2.7     6.7    39.5      2.2      5.8     38.4      1.9      4.6
# 2     2.9     5.9    48.9      1.7      5.3     32.5      2.1      5.7
# 3     3.2     8.7    37.2      1.9      5.0     37.5      1.6      4.5
# 4     2.7     7.3    37.3      2.7      6.3     43.1      1.7      5.2
#
#    RC3_FG%  AB3_FGM  AB3_FGA  AB3_FG%
# 0     42.6      8.5     25.2     33.7
# 1     42.2     14.3     40.2     35.6
# 2     36.6     10.9     28.2     38.5
# 3     35.9     11.0     32.3     33.9
# 4     33.1     11.9     32.4     36.8

# %%
# Calculate Total_FGA
shot_zone_focused_df['Total_FGA'] = (shot_zone_focused_df['RA_FGA'] 
                                     + shot_zone_focused_df['NRA_FGA']
                                     + shot_zone_focused_df['MR_FGA']
                                     + shot_zone_focused_df['LC3_FGA']
                                     + shot_zone_focused_df['RC3_FGA']
                                     + shot_zone_focused_df['AB3_FGA'])

# Calculate Total_FGM
shot_zone_focused_df['Total_FGM'] = (shot_zone_focused_df['RA_FGM'] 
                                     + shot_zone_focused_df['NRA_FGM']
                                     + shot_zone_focused_df['MR_FGM']
                                     + shot_zone_focused_df['LC3_FGM']
                                     + shot_zone_focused_df['RC3_FGM']
                                     + shot_zone_focused_df['AB3_FGM'])

# Calculate total_points
shot_zone_focused_df['Total_Points'] = ((shot_zone_focused_df['RA_FGM'] * 2)
                                        + (shot_zone_focused_df['NRA_FGM'] * 2)
                                        + (shot_zone_focused_df['MR_FGM'] * 2)
                                        + (shot_zone_focused_df['LC3_FGM'] * 3)
                                        + (shot_zone_focused_df['RC3_FGM'] * 3)
                                        + (shot_zone_focused_df['AB3_FGM'] * 3))

# ---

# Proportion of shots taken from RA
shot_zone_focused_df['RA_PA'] = (shot_zone_focused_df['RA_FGA'] / shot_zone_focused_df['Total_FGA'])

# Proportion of shots taken from NRA
shot_zone_focused_df['NRA_PA'] = (shot_zone_focused_df['NRA_FGA'] / shot_zone_focused_df['Total_FGA'])

# Proportion of shots taken from MR
shot_zone_focused_df['MR_PA'] = (shot_zone_focused_df['MR_FGA'] / shot_zone_focused_df['Total_FGA'])

# Proportion of shots taken from LC3
shot_zone_focused_df['LC3_PA'] = (shot_zone_focused_df['LC3_FGA'] / shot_zone_focused_df['Total_FGA'])

# Proportion of shots taken from RC3
shot_zone_focused_df['RC3_PA'] = (shot_zone_focused_df['RC3_FGA'] / shot_zone_focused_df['Total_FGA'])

# Proportion of shots taken from AB3
shot_zone_focused_df['AB3_PA'] = (shot_zone_focused_df['AB3_FGA'] / shot_zone_focused_df['Total_FGA'])

# ---

# Calculate the expected value of restricted area shots
shot_zone_focused_df['EV_RA'] = 2 * (shot_zone_focused_df['RA_FG%'] / 100)

# Calculate the expected value of non-restricted area shots
shot_zone_focused_df['EV_NRA'] = 2 * (shot_zone_focused_df['NRA_FG%'] / 100)

# Calculate the expected value of shots in the paint
shot_zone_focused_df['EV_Paint'] = ((shot_zone_focused_df['EV_NRA'] + shot_zone_focused_df['EV_RA']) / 2)

# --

# Calculate the expected value of mid-range shots
shot_zone_focused_df['EV_MR'] = 2 * (shot_zone_focused_df['MR_FG%'] / 100)

# --

# Calculate the expected value of left corner 3 shots
shot_zone_focused_df['EV_LC3'] = 3 * (shot_zone_focused_df['LC3_FG%'] / 100)

# Calculate the expected value of right corner 3 shots
shot_zone_focused_df['EV_RC3'] = 3 * (shot_zone_focused_df['RC3_FG%'] / 100)

# Calculate the expected value of above break 3 shots
shot_zone_focused_df['EV_AB3'] = 3 * (shot_zone_focused_df['AB3_FG%'] / 100)

# Calculate the expected value of threes
shot_zone_focused_df['EV_3'] = ((shot_zone_focused_df['EV_LC3'] 
                                 + shot_zone_focused_df['EV_RC3'] 
                                 + shot_zone_focused_df['EV_AB3']) / 3)

#--

shot_zone_focused_df[['Team',
                      'EV_RA','EV_NRA', 'EV_Paint',
                      'EV_MR', 
                      'EV_LC3','EV_RC3','EV_AB3','EV_3']]
# Out:
# /var/folders/4t/702khcbn5fddjkrmtys9tr2m0000gp/T/ipykernel_26070/1325865441.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shot_zone_focused_df['Total_FGA'] = (shot_zone_focused_df['RA_FGA']
# /var/folders/4t/702khcbn5fddjkrmtys9tr2m0000gp/T/ipykernel_26070/1325865441.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shot_zone_focused_df['Total_FGM'] = (shot_zone_focused_df['RA_FGM']
#                       Team  EV_RA  EV_NRA  EV_Paint  EV_MR  EV_LC3  EV_RC3  \
# 0            Atlanta Hawks  1.292   0.836     1.064  0.818   1.158   1.278
# 1           Boston Celtics  1.420   0.894     1.157  0.790   1.152   1.266
# 2            Brooklyn Nets  1.210   0.784     0.997  0.978   0.975   1.098
# 3        Charlotte Hornets  1.232   0.760     0.996  0.744   1.125   1.077
# 4            Chicago Bulls  1.242   1.018     1.130  0.746   1.293   0.993
# 5      Cleveland Cavaliers  1.294   1.074     1.184  0.866   1.284   1.254
# 6         Dallas Mavericks  1.402   0.900     1.151  0.862   1.164   1.152
# 7           Denver Nuggets  1.334   0.954     1.144  0.810   1.317   1.260
# 8          Detroit Pistons  1.338   0.846     1.092  0.816   0.951   1.158
# 9    Golden State Warriors  1.310   0.790     1.050  0.694   1.140   1.245
# 10         Houston Rockets  1.324   0.752     1.038  0.740   1.125   1.164
# 11          Indiana Pacers  1.360   0.962     1.161  0.842   1.362   1.326
# 12             LA Clippers  1.288   0.872     1.080  0.814   1.182   1.266
# 13      Los Angeles Lakers  1.412   0.846     1.129  0.778   1.215   1.158
# 14       Memphis Grizzlies  1.410   0.850     1.130  0.892   1.026   1.182
# 15              Miami Heat  1.244   0.860     1.052  0.752   1.206   1.146
# 16         Milwaukee Bucks  1.326   0.904     1.115  0.836   1.404   1.389
# 17  Minnesota Timberwolves  1.330   0.798     1.064  0.752   0.972   1.116
# 18    New Orleans Pelicans  1.240   0.736     0.988  0.864   1.170   0.882
# 19         New York Knicks  1.350   0.996     1.173  0.864   1.116   1.230
# 20   Oklahoma City Thunder  1.326   0.908     1.117  0.938   1.053   1.086
# 21           Orlando Magic  1.354   0.822     1.088  0.764   0.957   1.131
# 22      Philadelphia 76ers  1.246   0.862     1.054  0.720   1.008   1.098
# 23            Phoenix Suns  1.430   0.866     1.148  0.934   1.344   1.128
# 24  Portland Trail Blazers  1.234   0.696     0.965  0.856   1.041   1.140
# 25        Sacramento Kings  1.434   1.008     1.221  0.894   1.161   1.149
# 26       San Antonio Spurs  1.326   0.804     1.065  0.772   1.062   1.254
# 27         Toronto Raptors  1.230   0.878     1.054  0.792   1.215   1.089
# 28               Utah Jazz  1.326   0.922     1.124  0.678   1.278   1.242
# 29      Washington Wizards  1.386   0.746     1.066  0.712   0.942   1.125
#
#     EV_AB3   EV_3
# 0    1.011  1.149
# 1    1.068  1.162
# 2    1.155  1.076
# 3    1.017  1.073
# 4    1.104  1.130
# 5    1.212  1.250
# 6    1.125  1.147
# 7    1.125  1.234
# 8    1.104  1.071
# 9    1.065  1.150
# 10   0.942  1.077
# 11   1.053  1.247
# 12   1.074  1.174
# 13   1.035  1.136
# 14   1.122  1.110
# 15   1.104  1.152
# 16   1.098  1.297
# 17   1.152  1.080
# 18   1.005  1.019
# 19   1.173  1.173
# 20   1.026  1.055
# 21   0.894  0.994
# 22   1.005  1.037
# 23   1.089  1.187
# 24   0.978  1.053
# 25   0.978  1.096
# 26   1.014  1.110
# 27   0.987  1.097
# 28   1.050  1.190
# 29   0.978  1.015

# %%
shot_zone_focused_df['EV Total'] = (
    (shot_zone_focused_df['EV_RA']) +
    shot_zone_focused_df['EV_NRA'] +
    shot_zone_focused_df['EV_MR'] +
    shot_zone_focused_df['EV_LC3'] +
    shot_zone_focused_df['EV_RC3'] +
    shot_zone_focused_df['EV_AB3']
)

shot_zone_focused_df[['Team','EV Total']]
# Out:
#                       Team  EV Total
# 0            Atlanta Hawks     6.393
# 1           Boston Celtics     6.590
# 2            Brooklyn Nets     6.200
# 3        Charlotte Hornets     5.955
# 4            Chicago Bulls     6.396
# 5      Cleveland Cavaliers     6.984
# 6         Dallas Mavericks     6.605
# 7           Denver Nuggets     6.800
# 8          Detroit Pistons     6.213
# 9    Golden State Warriors     6.244
# 10         Houston Rockets     6.047
# 11          Indiana Pacers     6.905
# 12             LA Clippers     6.496
# 13      Los Angeles Lakers     6.444
# 14       Memphis Grizzlies     6.482
# 15              Miami Heat     6.312
# 16         Milwaukee Bucks     6.957
# 17  Minnesota Timberwolves     6.120
# 18    New Orleans Pelicans     5.897
# 19         New York Knicks     6.729
# 20   Oklahoma City Thunder     6.337
# 21           Orlando Magic     5.922
# 22      Philadelphia 76ers     5.939
# 23            Phoenix Suns     6.791
# 24  Portland Trail Blazers     5.945
# 25        Sacramento Kings     6.624
# 26       San Antonio Spurs     6.232
# 27         Toronto Raptors     6.191
# 28               Utah Jazz     6.496
# 29      Washington Wizards     5.889

# %%
# Calculate how many of each type of shot the teams should take given their total EV: RA
# Calculate the ideal proportiong of RA, the number attempts, the number of makes based on their expected proportions
shot_zone_focused_df['EV_RA_Proportion'] = shot_zone_focused_df['EV_RA'] / shot_zone_focused_df['EV Total']

shot_zone_focused_df['EV_RA_Attempts'] = shot_zone_focused_df['EV_RA_Proportion'] * shot_zone_focused_df['Total_FGA']
shot_zone_focused_df['EV_RA_Makes'] = shot_zone_focused_df['EV_RA_Proportion'] * shot_zone_focused_df['Total_FGM']

# This is going to read we want to take less or more shots 
shot_zone_focused_df['EV_RA_Attempts_Diff'] = shot_zone_focused_df['EV_RA_Attempts'] - shot_zone_focused_df['RA_FGA']
shot_zone_focused_df['EV_RA_Makes_Diff'] = shot_zone_focused_df['EV_RA_Makes'] - shot_zone_focused_df['RA_FGM']

shot_zone_focused_df[['Team'
                      ,'RA_PA','EV_RA_Proportion'
                      ,'RA_FGM','RA_FGA'
                      ,'EV_RA_Makes','EV_RA_Attempts'
                      ,'EV_RA_Makes_Diff', 'EV_RA_Attempts_Diff']]
# Out:
#                       Team     RA_PA  EV_RA_Proportion  RA_FGM  RA_FGA  \
# 0            Atlanta Hawks  0.327492          0.202096    19.3    29.9
# 1           Boston Celtics  0.230601          0.215478    15.0    21.1
# 2            Brooklyn Nets  0.290476          0.195161    14.8    24.4
# 3        Charlotte Hornets  0.274247          0.206885    15.1    24.6
# 4            Chicago Bulls  0.308615          0.194184    17.6    28.3
# 5      Cleveland Cavaliers  0.322835          0.185281    18.5    28.7
# 6         Dallas Mavericks  0.263277          0.212263    16.3    23.3
# 7           Denver Nuggets  0.341928          0.196176    20.4    30.5
# 8          Detroit Pistons  0.285231          0.215355    16.9    25.3
# 9    Golden State Warriors  0.269859          0.209801    16.3    24.8
# 10         Houston Rockets  0.303095          0.218952    18.8    28.4
# 11          Indiana Pacers  0.285223          0.196959    16.9    24.9
# 12             LA Clippers  0.290888          0.198276    16.0    24.9
# 13      Los Angeles Lakers  0.290398          0.219119    17.5    24.8
# 14       Memphis Grizzlies  0.288172          0.217525    18.9    26.8
# 15              Miami Heat  0.267898          0.197085    14.4    23.2
# 16         Milwaukee Bucks  0.279532          0.190599    15.9    23.9
# 17  Minnesota Timberwolves  0.274738          0.217320    15.7    23.6
# 18    New Orleans Pelicans  0.301446          0.210276    16.8    27.1
# 19         New York Knicks  0.295533          0.200624    17.4    25.8
# 20   Oklahoma City Thunder  0.268108          0.209247    16.5    24.8
# 21           Orlando Magic  0.321513          0.228639    18.4    27.2
# 22      Philadelphia 76ers  0.309942          0.209800    16.5    26.5
# 23            Phoenix Suns  0.197183          0.210573    12.0    16.8
# 24  Portland Trail Blazers  0.344828          0.207569    19.1    31.0
# 25        Sacramento Kings  0.219731          0.216486    14.1    19.6
# 26       San Antonio Spurs  0.306193          0.212773    17.7    26.7
# 27         Toronto Raptors  0.356119          0.198675    19.9    32.3
# 28               Utah Jazz  0.248235          0.204126    14.0    21.1
# 29      Washington Wizards  0.280177          0.235354    17.5    25.3
#
#     EV_RA_Makes  EV_RA_Attempts  EV_RA_Makes_Diff  EV_RA_Attempts_Diff
# 0      8.649711       18.451369        -10.650289           -11.448631
# 1      9.028528       19.716237         -5.971472            -1.383763
# 2      7.435645       16.393548         -7.364355            -8.006452
# 3      7.944383       18.557582         -7.155617            -6.042418
# 4      8.311069       17.806660         -9.288931           -10.493340
# 5      8.319101       16.471449        -10.180899           -12.228551
# 6      9.106101       18.785314         -7.193899            -4.514686
# 7      8.847559       17.498941        -11.552441           -13.001059
# 8      8.937228       19.101980         -7.962772            -6.198020
# 9      8.643818       19.280750         -7.656182            -5.519250
# 10     9.086489       20.515760         -9.713511            -7.884240
# 11     8.410138       17.194497         -8.489862            -7.705503
# 12     7.931034       16.972414         -8.068966            -7.927586
# 13     8.874302       18.712725         -8.625698            -6.087275
# 14     9.832151       20.229867         -9.067849            -6.570133
# 15     7.725729       17.067554         -6.674271            -6.132446
# 16     7.814575       16.296248         -8.085425            -7.603752
# 17     8.605882       18.667810         -7.094118            -4.932190
# 18     8.326946       18.903849         -8.473054            -8.196151
# 19     8.747214       17.514490         -8.652786            -8.285510
# 20     9.060407       19.355373         -7.439593            -5.444627
# 21     8.734009       19.342857         -9.665991            -7.857143
# 22     7.951406       17.937868         -8.548594            -8.562132
# 23     8.422913       17.940804         -3.577087             1.140804
# 24     8.282019       18.660488        -10.817981           -12.339512
# 25     9.243931       19.310507         -4.856069            -0.289493
# 26     8.489634       18.553787         -9.210366            -8.146213
# 27     8.364238       18.019868        -11.535762           -14.280132
# 28     8.001724       17.350677         -5.998276            -3.749323
# 29     9.390627       21.252471         -8.109373            -4.047529

# %%
# Calculate how many of each type of shot the teams should take given their total EV: NRA
# Calculate the ideal proportion of NRA, the number attempts, the number of makes based on their expected proportions
shot_zone_focused_df['EV_NRA_Proportion'] = shot_zone_focused_df['EV_NRA'] / shot_zone_focused_df['EV Total']

shot_zone_focused_df['EV_NRA_Attempts'] = shot_zone_focused_df['EV_NRA_Proportion'] * shot_zone_focused_df['Total_FGA']
shot_zone_focused_df['EV_NRA_Makes'] = shot_zone_focused_df['EV_NRA_Proportion'] * shot_zone_focused_df['Total_FGM']

# This is going to read we want to take less or more shots 
shot_zone_focused_df['EV_NRA_Attempts_Diff'] = shot_zone_focused_df['EV_NRA_Attempts'] - shot_zone_focused_df['NRA_FGA']
shot_zone_focused_df['EV_NRA_Makes_Diff'] = shot_zone_focused_df['EV_NRA_Makes'] - shot_zone_focused_df['NRA_FGM']

shot_zone_focused_df[['Team'
                      ,'NRA_PA','EV_NRA_Proportion'
                      ,'NRA_FGM','NRA_FGA'
                      ,'EV_NRA_Makes','EV_NRA_Attempts'
                      ,'EV_NRA_Makes_Diff', 'EV_NRA_Attempts_Diff']]
# Out:
#                       Team    NRA_PA  EV_NRA_Proportion  NRA_FGM  NRA_FGA  \
# 0            Atlanta Hawks  0.219058           0.130768      8.4     20.0
# 1           Boston Celtics  0.143169           0.135660      5.8     13.1
# 2            Brooklyn Nets  0.172619           0.126452      5.7     14.5
# 3        Charlotte Hornets  0.162765           0.127624      5.6     14.6
# 4            Chicago Bulls  0.133043           0.159162      6.2     12.2
# 5      Cleveland Cavaliers  0.142857           0.153780      6.8     12.7
# 6         Dallas Mavericks  0.218079           0.136260      8.7     19.3
# 7           Denver Nuggets  0.208520           0.140294      8.9     18.6
# 8          Detroit Pistons  0.196167           0.136166      7.4     17.4
# 9    Golden State Warriors  0.198041           0.126521      7.2     18.2
# 10         Houston Rockets  0.199573           0.124359      7.0     18.7
# 11          Indiana Pacers  0.203895           0.139319      8.5     17.8
# 12             LA Clippers  0.237150           0.134236      8.8     20.3
# 13      Los Angeles Lakers  0.204918           0.131285      7.4     17.5
# 14       Memphis Grizzlies  0.246237           0.131132      9.8     22.9
# 15              Miami Heat  0.218245           0.136248      8.1     18.9
# 16         Milwaukee Bucks  0.136842           0.129941      5.3     11.7
# 17  Minnesota Timberwolves  0.185099           0.130392      6.4     15.9
# 18    New Orleans Pelicans  0.199110           0.124809      6.6     17.9
# 19         New York Knicks  0.184422           0.148016      8.0     16.1
# 20   Oklahoma City Thunder  0.202162           0.143285      8.5     18.7
# 21           Orlando Magic  0.156028           0.138804      5.4     13.2
# 22      Philadelphia 76ers  0.171930           0.145142      6.3     14.7
# 23            Phoenix Suns  0.228873           0.127522      8.5     19.5
# 24  Portland Trail Blazers  0.165740           0.117073      5.2     14.9
# 25        Sacramento Kings  0.226457           0.152174     10.2     20.2
# 26       San Antonio Spurs  0.142202           0.129012      5.0     12.4
# 27         Toronto Raptors  0.195149           0.141819      7.8     17.7
# 28               Utah Jazz  0.237647           0.141933      9.3     20.2
# 29      Washington Wizards  0.201550           0.126677      6.8     18.2
#
#     EV_NRA_Makes  EV_NRA_Attempts  EV_NRA_Makes_Diff  EV_NRA_Attempts_Diff
# 0       5.596872        11.939121          -2.803128             -8.060879
# 1       5.684158        12.412898          -0.115842             -0.687102
# 2       4.817806        10.621935          -0.882194             -3.878065
# 3       4.900756        11.447859          -0.699244             -3.152141
# 4       6.812133        14.595153           0.612133              2.395153
# 5       6.904725        13.671048           0.104725              0.971048
# 6       5.845572        12.059046          -2.854428             -7.240954
# 7       6.327265        12.514235          -2.572735             -6.085765
# 8       5.650893        12.077933          -1.749107             -5.322067
# 9       5.212684        11.627322          -1.987316             -6.572678
# 10      5.160906        11.652456          -1.839094             -7.047544
# 11      5.948936        12.162578          -2.551064             -5.637422
# 12      5.369458        11.490640          -3.430542             -8.809360
# 13      5.317039        11.211732          -2.082961             -6.288268
# 14      5.927183        12.195310          -3.872817            -10.704690
# 15      5.340938        11.799113          -2.759062             -7.100887
# 16      5.327584        11.109961           0.027584             -0.590039
# 17      5.163529        11.200686          -1.236471             -4.699314
# 18      4.942445        11.220349          -1.657555             -6.679651
# 19      6.453500        12.921801          -1.546500             -3.178199
# 20      6.204261        13.253906          -2.295739             -5.446094
# 21      5.302330        11.742857          -0.097670             -1.457143
# 22      5.500892        12.409665          -0.799108             -2.290335
# 23      5.100869        10.864851          -3.399131             -8.635149
# 24      4.671220        10.524878          -0.528780             -4.375122
# 25      6.497826        13.573913          -3.702174             -6.626087
# 26      5.147561        11.249807           0.147561             -1.150193
# 27      5.970570        12.862962          -1.829430             -4.837038
# 28      5.563793        12.064347          -3.736207             -8.135653
# 29      5.054407        11.438920          -1.745593             -6.761080

# %%
# Calculate how many of each type of shot the teams should take given their total EV: MR
# Calculate the ideal proportiong of MR, the number attempts, the number of makes based on their expected proportions
shot_zone_focused_df['EV_MR_Proportion'] = shot_zone_focused_df['EV_MR'] / shot_zone_focused_df['EV Total']

shot_zone_focused_df['EV_MR_Attempts'] = shot_zone_focused_df['EV_MR_Proportion'] * shot_zone_focused_df['Total_FGA']
shot_zone_focused_df['EV_MR_Makes'] = shot_zone_focused_df['EV_MR_Proportion'] * shot_zone_focused_df['Total_FGM']

# This is going to read we want to take less or more shots 
shot_zone_focused_df['EV_MR_Attempts_Diff'] = shot_zone_focused_df['EV_MR_Attempts'] - shot_zone_focused_df['MR_FGA']
shot_zone_focused_df['EV_MR_Makes_Diff'] = shot_zone_focused_df['EV_MR_Makes'] - shot_zone_focused_df['MR_FGM']

shot_zone_focused_df[['Team'
                      ,'MR_PA','EV_MR_Proportion'
                      ,'MR_FGM','MR_FGA'
                      ,'EV_MR_Makes','EV_MR_Attempts'
                      ,'EV_MR_Makes_Diff', 'EV_MR_Attempts_Diff']]
# Out:
#                       Team     MR_PA  EV_MR_Proportion  MR_FGM  MR_FGA  \
# 0            Atlanta Hawks  0.060241          0.127952     2.2     5.5
# 1           Boston Celtics  0.073224          0.119879     2.7     6.7
# 2            Brooklyn Nets  0.070238          0.157742     2.9     5.9
# 3        Charlotte Hornets  0.096990          0.124937     3.2     8.7
# 4            Chicago Bulls  0.079607          0.116635     2.7     7.3
# 5      Cleveland Cavaliers  0.086614          0.123998     3.3     7.7
# 6         Dallas Mavericks  0.115254          0.130507     4.4    10.2
# 7           Denver Nuggets  0.109865          0.119118     4.0     9.8
# 8          Detroit Pistons  0.101466          0.131338     3.7     9.0
# 9    Golden State Warriors  0.083787          0.111147     2.7     7.7
# 10         Houston Rockets  0.108858          0.122375     3.8    10.2
# 11          Indiana Pacers  0.124857          0.121941     4.6    10.9
# 12             LA Clippers  0.074766          0.125308     2.6     6.4
# 13      Los Angeles Lakers  0.117096          0.120732     3.9    10.0
# 14       Memphis Grizzlies  0.056989          0.137612     2.4     5.3
# 15              Miami Heat  0.071594          0.119138     2.3     6.2
# 16         Milwaukee Bucks  0.148538          0.120167     5.3    12.7
# 17  Minnesota Timberwolves  0.075669          0.122876     2.5     6.5
# 18    New Orleans Pelicans  0.126808          0.146515     4.9    11.4
# 19         New York Knicks  0.109966          0.128399     4.2     9.6
# 20   Oklahoma City Thunder  0.108108          0.148020     4.7    10.0
# 21           Orlando Magic  0.093381          0.129010     3.0     7.9
# 22      Philadelphia 76ers  0.101754          0.121233     3.1     8.7
# 23            Phoenix Suns  0.124413          0.137535     5.0    10.6
# 24  Portland Trail Blazers  0.090100          0.143987     3.5     8.1
# 25        Sacramento Kings  0.162556          0.134964     6.5    14.5
# 26       San Antonio Spurs  0.100917          0.123877     3.4     8.8
# 27         Toronto Raptors  0.084895          0.127928     3.0     7.7
# 28               Utah Jazz  0.071765          0.104372     2.1     6.1
# 29      Washington Wizards  0.106312          0.120903     3.4     9.6
#
#     EV_MR_Makes  EV_MR_Attempts  EV_MR_Makes_Diff  EV_MR_Attempts_Diff
# 0      5.476365       11.682059          3.276365             6.182059
# 1      5.022914       10.968892          2.322914             4.268892
# 2      6.009968       13.250323          3.109968             7.350323
# 3      4.797582       11.206851          1.597582             2.506851
# 4      4.991995       10.695466          2.291995             3.395466
# 5      5.567497       11.023396          2.267497             3.323396
# 6      5.598759       11.549886          1.198759             1.349886
# 7      5.372206       10.625294          1.372206             0.825294
# 8      5.450507       11.649638          1.750507             2.649638
# 9      4.579244       10.214382          1.879244             2.514382
# 10     5.078551       11.466512          1.278551             1.266512
# 11     5.206865       10.645416          0.606865            -0.254584
# 12     5.012315       10.726355          2.412315             4.326355
# 13     4.889665       10.310552          0.989665             0.310552
# 14     6.220056       12.797902          3.820056             7.497902
# 15     4.670215       10.317364          2.370215             4.117364
# 16     4.926836       10.274256         -0.373164            -2.425744
# 17     4.865882       10.555033          2.365882             4.055033
# 18     5.802001       13.171714          0.902001             1.771714
# 19     5.598217       11.209273          1.398217             1.609273
# 20     6.409247       13.691810          1.709247             3.691810
# 21     4.928200       10.914286          1.928200             3.014286
# 22     4.594713       10.365381          1.494713             1.665381
# 23     5.501399       11.717980          0.501399             1.117980
# 24     5.745063       12.944390          2.245063             4.844390
# 25     5.762953       12.038768         -0.737047            -2.461232
# 26     4.942683       10.802054          1.542683             2.002054
# 27     5.385754       11.603037          2.385754             3.903037
# 28     4.091379        8.871613          1.991379             2.771613
# 29     4.824045       10.917575          1.424045             1.317575

# %%
# # Calculate standard deviation of shooting percentage for each shot type
# shot_zone_focused_df['MR_StdDev'] = np.sqrt(
#     shot_zone_focused_df['MR_PA'] * (1 - shot_zone_focused_df['MR_PA']) / shot_zone_focused_df['MR_FGA']
# )

# # Add confidence intervals to your EV calculations
# shot_zone_focused_df['MR_EV_Lower'] = (shot_zone_focused_df['MR_PA'] - 1.96 * shot_zone_focused_df['MR_StdDev']) * 2
# shot_zone_focused_df['MR_EV_Upper'] = (shot_zone_focused_df['MR_PA'] + 1.96 * shot_zone_focused_df['MR_StdDev']) * 2

# %%
# Calculate how many of each type of shot the teams should take given their total EV: LC3
# Calculate the ideal proportiong of LC3, the number attempts, the number of makes based on their expected proportions
shot_zone_focused_df['EV_LC3_Proportion'] = shot_zone_focused_df['EV_LC3'] / shot_zone_focused_df['EV Total']

shot_zone_focused_df['EV_LC3_Attempts'] = shot_zone_focused_df['EV_LC3_Proportion'] * shot_zone_focused_df['Total_FGA']
shot_zone_focused_df['EV_LC3_Makes'] = shot_zone_focused_df['EV_LC3_Proportion'] * shot_zone_focused_df['Total_FGM']

# This is going to read we want to take less or more shots 
shot_zone_focused_df['EV_LC3_Attempts_Diff'] = shot_zone_focused_df['EV_LC3_Attempts'] - shot_zone_focused_df['LC3_FGA']
shot_zone_focused_df['EV_LC3_Makes_Diff'] = shot_zone_focused_df['EV_LC3_Makes'] - shot_zone_focused_df['LC3_FGM']

shot_zone_focused_df[['Team'
                      ,'LC3_PA','EV_LC3_Proportion'
                      ,'LC3_FGM','LC3_FGA'
                      ,'EV_LC3_Makes','EV_LC3_Attempts'
                      ,'EV_LC3_Makes_Diff', 'EV_LC3_Attempts_Diff']]
# Out:
#                       Team    LC3_PA  EV_LC3_Proportion  LC3_FGM  LC3_FGA  \
# 0            Atlanta Hawks  0.050383           0.181136      1.8      4.6
# 1           Boston Celtics  0.063388           0.174810      2.2      5.8
# 2            Brooklyn Nets  0.063095           0.157258      1.7      5.3
# 3        Charlotte Hornets  0.055741           0.188917      1.9      5.0
# 4            Chicago Bulls  0.068702           0.202158      2.7      6.3
# 5      Cleveland Cavaliers  0.065242           0.183849      2.5      5.8
# 6         Dallas Mavericks  0.054237           0.176230      1.8      4.8
# 7           Denver Nuggets  0.035874           0.193676      1.4      3.2
# 8          Detroit Pistons  0.049605           0.153066      1.4      4.4
# 9    Golden State Warriors  0.058760           0.182575      2.0      5.4
# 10         Houston Rockets  0.035219           0.186043      1.2      3.3
# 11          Indiana Pacers  0.049255           0.197248      1.9      4.3
# 12             LA Clippers  0.047897           0.181958      1.6      4.1
# 13      Los Angeles Lakers  0.048009           0.188547      1.6      4.1
# 14       Memphis Grizzlies  0.065591           0.158284      2.1      6.1
# 15              Miami Heat  0.072748           0.191065      2.5      6.3
# 16         Milwaukee Bucks  0.047953           0.201811      1.9      4.1
# 17  Minnesota Timberwolves  0.064028           0.158824      1.8      5.5
# 18    New Orleans Pelicans  0.045606           0.198406      1.6      4.1
# 19         New York Knicks  0.063001           0.165849      2.1      5.5
# 20   Oklahoma City Thunder  0.051892           0.166167      1.7      4.8
# 21           Orlando Magic  0.065012           0.161601      1.8      5.5
# 22      Philadelphia 76ers  0.047953           0.169726      1.4      4.1
# 23            Phoenix Suns  0.068075           0.197909      2.6      5.8
# 24  Portland Trail Blazers  0.043382           0.175105      1.4      3.9
# 25        Sacramento Kings  0.057175           0.175272      2.0      5.1
# 26       San Antonio Spurs  0.056193           0.170411      1.8      4.9
# 27         Toronto Raptors  0.059537           0.196253      2.2      5.4
# 28               Utah Jazz  0.061176           0.196736      2.2      5.2
# 29      Washington Wizards  0.038760           0.159959      1.1      3.5
#
#     EV_LC3_Makes  EV_LC3_Attempts  EV_LC3_Makes_Diff  EV_LC3_Attempts_Diff
# 0       7.752604        16.537682           5.952604             11.937682
# 1       7.324552        15.995144           5.124552             10.195144
# 2       5.991532        13.209677           4.291532              7.909677
# 3       7.254408        16.945844           5.354408             11.945844
# 4       8.652345        18.537852           5.952345             12.237852
# 5       8.254811        16.344158           5.754811             10.544158
# 6       7.560273        15.596366           5.760273             10.796366
# 7       8.734809        17.275941           7.334809             14.075941
# 8       6.352245        13.576968           4.952245              9.176968
# 9       7.522101        16.778668           5.522101             11.378668
# 10      7.720771        17.432198           6.520771             14.132198
# 11      8.422505        17.219783           6.522505             12.919783
# 12      7.278325        15.575616           5.678325             11.475616
# 13      7.636173        16.101955           6.036173             12.001955
# 14      7.154459        14.720457           5.054459              8.620457
# 15      7.489734        16.546198           4.989734             10.246198
# 16      8.274256        17.254851           6.374256             13.154851
# 17      6.289412        13.642941           4.489412              8.142941
# 18      7.856876        17.836697           6.256876             13.736697
# 19      7.231030        14.478645           5.131030              8.978645
# 20      7.195029        15.370443           5.495029             10.570443
# 21      6.173151        13.671429           4.373151              8.171429
# 22      6.432598        14.511534           5.032598             10.411534
# 23      7.916360        16.861847           5.316360             11.061847
# 24      6.986695        15.741951           5.586695             11.841951
# 25      7.484103        15.634239           5.484103             10.534239
# 26      6.799390        14.859820           4.999390              9.959820
# 27      8.262236        17.800113           6.062236             12.400113
# 28      7.712069        16.722599           5.512069             11.522599
# 29      6.382374        14.444320           5.282374             10.944320

# %%
# Calculate how many of each type of shot the teams should take given their total EV: RC3
# Calculate the ideal proportiong of RC3, the number attempts, the number of makes based on their expected proportions
shot_zone_focused_df['EV_RC3_Proportion'] = shot_zone_focused_df['EV_RC3'] / shot_zone_focused_df['EV Total']

shot_zone_focused_df['EV_RC3_Attempts'] = shot_zone_focused_df['EV_RC3_Proportion'] * shot_zone_focused_df['Total_FGA']
shot_zone_focused_df['EV_RC3_Makes'] = shot_zone_focused_df['EV_RC3_Proportion'] * shot_zone_focused_df['Total_FGM']

# This is going to read we want to take less or more shots 
shot_zone_focused_df['EV_RC3_Attempts_Diff'] = shot_zone_focused_df['EV_RC3_Attempts'] - shot_zone_focused_df['RC3_FGA']
shot_zone_focused_df['EV_RC3_Makes_Diff'] = shot_zone_focused_df['EV_RC3_Makes'] - shot_zone_focused_df['RC3_FGM']

shot_zone_focused_df[['Team'
                      ,'RC3_PA','EV_RC3_Proportion'
                      ,'RC3_FGM','RC3_FGA'
                      ,'EV_RC3_Makes','EV_RC3_Attempts'
                      ,'EV_RC3_Makes_Diff', 'EV_RC3_Attempts_Diff']]
# Out:
#                       Team    RC3_PA  EV_RC3_Proportion  RC3_FGM  RC3_FGA  \
# 0            Atlanta Hawks  0.066813           0.199906      2.6      6.1
# 1           Boston Celtics  0.050273           0.192109      1.9      4.6
# 2            Brooklyn Nets  0.067857           0.177097      2.1      5.7
# 3        Charlotte Hornets  0.050167           0.180856      1.6      4.5
# 4            Chicago Bulls  0.056707           0.155253      1.7      5.2
# 5      Cleveland Cavaliers  0.057368           0.179553      2.1      5.1
# 6         Dallas Mavericks  0.051977           0.174413      1.8      4.6
# 7           Denver Nuggets  0.035874           0.185294      1.4      3.2
# 8          Detroit Pistons  0.062007           0.186383      2.1      5.5
# 9    Golden State Warriors  0.050054           0.199391      1.9      4.6
# 10         Houston Rockets  0.045891           0.192492      1.7      4.3
# 11          Indiana Pacers  0.053837           0.192035      2.1      4.7
# 12             LA Clippers  0.053738           0.194889      1.9      4.6
# 13      Los Angeles Lakers  0.032787           0.179702      1.1      2.8
# 14       Memphis Grizzlies  0.050538           0.182351      1.8      4.7
# 15              Miami Heat  0.065820           0.181559      2.2      5.7
# 16         Milwaukee Bucks  0.052632           0.199655      2.1      4.5
# 17  Minnesota Timberwolves  0.058207           0.182353      1.9      5.0
# 18    New Orleans Pelicans  0.045606           0.149568      1.2      4.1
# 19         New York Knicks  0.061856           0.182791      2.2      5.4
# 20   Oklahoma City Thunder  0.040000           0.171374      1.4      3.7
# 21           Orlando Magic  0.055556           0.190983      1.8      4.7
# 22      Philadelphia 76ers  0.045614           0.184880      1.4      3.9
# 23            Phoenix Suns  0.065728           0.166102      2.1      5.6
# 24  Portland Trail Blazers  0.064516           0.191758      2.2      5.8
# 25        Sacramento Kings  0.044843           0.173460      1.5      4.0
# 26       San Antonio Spurs  0.052752           0.201220      1.9      4.6
# 27         Toronto Raptors  0.058434           0.175901      1.9      5.3
# 28               Utah Jazz  0.057647           0.191195      2.0      4.9
# 29      Washington Wizards  0.032115           0.191034      1.1      2.9
#
#     EV_RC3_Makes  EV_RC3_Attempts  EV_RC3_Makes_Diff  EV_RC3_Attempts_Diff
# 0       8.555983        18.251431           5.955983             12.151431
# 1       8.049378        17.577997           6.149378             12.977997
# 2       6.747387        14.876129           4.647387              9.176129
# 3       6.944887        16.222821           5.344887             11.722821
# 4       6.644841        14.236726           4.944841              9.036726
# 5       8.061942        15.962285           5.961942             10.862285
# 6       7.482332        15.435579           5.682332             10.835579
# 7       8.356765        16.528235           6.956765             13.328235
# 8       7.734911        16.532207           5.634911             11.032207
# 9       8.214926        18.324071           6.314926             13.724071
# 10      7.988424        18.036514           6.288424             13.736514
# 11      8.199884        16.764634           6.099884             12.064634
# 12      7.795567        16.682512           5.895567             12.082512
# 13      7.277933        15.346555           6.177933             12.546555
# 14      8.242271        16.958655           6.442271             12.258655
# 15      7.117110        15.723004           4.917110             10.023004
# 16      8.185856        17.070505           6.085856             12.570505
# 17      7.221176        15.664118           5.321176             10.664118
# 18      5.922876        13.446125           4.722876              9.346125
# 19      7.969683        15.957646           5.769683             10.557646
# 20      7.420514        15.852138           6.020514             12.152138
# 21      7.295542        16.157143           5.495542             11.457143
# 22      7.006937        15.807207           5.606937             11.907207
# 23      6.644088        14.151907           4.544088              8.551907
# 24      7.651135        17.239024           5.451135             11.439024
# 25      7.406748        15.472645           5.906748             11.472645
# 26      8.028659        17.546341           6.128659             12.946341
# 27      7.405411        15.954175           5.505411             10.654175
# 28      7.494828        16.251539           5.494828             11.351539
# 29      7.622262        17.250382           6.522262             14.350382

# %%
# Calculate how many of each type of shot the teams should take given their total EV: AB3
# Calculate the ideal proportiong of AB3, the number attempts, the number of makes based on their expected proportions
shot_zone_focused_df['EV_AB3_Proportion'] = shot_zone_focused_df['EV_AB3'] / shot_zone_focused_df['EV Total']

shot_zone_focused_df['EV_AB3_Attempts'] = shot_zone_focused_df['EV_AB3_Proportion'] * shot_zone_focused_df['Total_FGA']
shot_zone_focused_df['EV_AB3_Makes'] = shot_zone_focused_df['EV_AB3_Proportion'] * shot_zone_focused_df['Total_FGM']

# This is going to read we want to take less or more shots 
shot_zone_focused_df['EV_AB3_Attempts_Diff'] = shot_zone_focused_df['EV_AB3_Attempts'] - shot_zone_focused_df['AB3_FGA']
shot_zone_focused_df['EV_AB3_Makes_Diff'] = shot_zone_focused_df['EV_AB3_Makes'] - shot_zone_focused_df['AB3_FGM']


shot_zone_focused_df[['Team'
                      ,'AB3_PA','EV_AB3_Proportion'
                      ,'AB3_FGM','AB3_FGA'
                      ,'EV_AB3_Makes','EV_AB3_Attempts'
                      ,'EV_AB3_Makes_Diff','EV_AB3_Attempts_Diff']]
# Out:
#                       Team    AB3_PA  EV_AB3_Proportion  AB3_FGM  AB3_FGA  \
# 0            Atlanta Hawks  0.276013           0.158142      8.5     25.2
# 1           Boston Celtics  0.439344           0.162064     14.3     40.2
# 2            Brooklyn Nets  0.335714           0.186290     10.9     28.2
# 3        Charlotte Hornets  0.360089           0.170781     11.0     32.3
# 4            Chicago Bulls  0.353326           0.172608     11.9     32.4
# 5      Cleveland Cavaliers  0.325084           0.173540     11.7     28.9
# 6         Dallas Mavericks  0.297175           0.170326      9.9     26.3
# 7           Denver Nuggets  0.267937           0.165441      9.0     23.9
# 8          Detroit Pistons  0.305524           0.177692     10.0     27.1
# 9    Golden State Warriors  0.339499           0.170564     11.1     31.2
# 10         Houston Rockets  0.307364           0.155780      9.0     28.8
# 11          Indiana Pacers  0.282932           0.152498      8.7     24.7
# 12             LA Clippers  0.295561           0.165333      9.1     25.3
# 13      Los Angeles Lakers  0.306792           0.160615      9.0     26.2
# 14       Memphis Grizzlies  0.292473           0.173095     10.2     27.2
# 15              Miami Heat  0.303695           0.174905      9.7     26.3
# 16         Milwaukee Bucks  0.334503           0.157827     10.5     28.6
# 17  Minnesota Timberwolves  0.342258           0.188235     11.3     29.4
# 18    New Orleans Pelicans  0.281424           0.170426      8.5     25.3
# 19         New York Knicks  0.285223           0.174320      9.7     24.9
# 20   Oklahoma City Thunder  0.329730           0.161906     10.5     30.5
# 21           Orlando Magic  0.308511           0.150963      7.8     26.1
# 22      Philadelphia 76ers  0.322807           0.169220      9.2     27.6
# 23            Phoenix Suns  0.315728           0.160359      9.8     26.9
# 24  Portland Trail Blazers  0.291435           0.164508      8.5     26.2
# 25        Sacramento Kings  0.289238           0.147645      8.4     25.8
# 26       San Antonio Spurs  0.341743           0.162709     10.1     29.8
# 27         Toronto Raptors  0.245865           0.159425      7.3     22.3
# 28               Utah Jazz  0.323529           0.161638      9.6     27.5
# 29      Washington Wizards  0.341085           0.166072     10.0     30.8
#
#     EV_AB3_Makes  EV_AB3_Attempts  EV_AB3_Makes_Diff  EV_AB3_Attempts_Diff
# 0       6.768466        14.438339          -1.731534            -10.761661
# 1       6.790470        14.828832          -7.509530            -25.371168
# 2       7.097661        15.648387          -3.802339            -12.551613
# 3       6.557985        15.319043          -4.442015            -16.980957
# 4       7.387617        15.828143          -4.512383            -16.571857
# 5       7.791924        15.427663          -3.908076            -13.472337
# 6       7.306964        15.073808          -2.593036            -11.226192
# 7       7.461397        14.757353          -1.538603             -9.142647
# 8       7.374215        15.761275          -2.625785            -11.338725
# 9       7.027226        15.674808          -4.072774            -15.525192
# 10      6.464859        14.596560          -2.535141            -14.203440
# 11      6.511673        13.313092          -2.188327            -11.386908
# 12      6.613300        14.152463          -2.486700            -11.147537
# 13      6.504888        13.716480          -2.495112            -12.483520
# 14      7.823882        16.097809          -2.376118            -11.102191
# 15      6.856274        15.146768          -2.843726            -11.153232
# 16      6.470893        13.494179          -4.029107            -15.105821
# 17      7.454118        16.169412          -3.845882            -13.230588
# 18      6.748855        15.321265          -1.751145             -9.978735
# 19      7.600357        15.218145          -2.099643             -9.681855
# 20      7.010541        14.976329          -3.489459            -15.523671
# 21      5.766768        12.771429          -2.033232            -13.328571
# 22      6.413453        14.468345          -2.786547            -13.131655
# 23      6.414372        13.662612          -3.385628            -13.237388
# 24      6.563869        14.789268          -1.936131            -11.410732
# 25      6.304438        13.169928          -2.095562            -12.630072
# 26      6.492073        14.188190          -3.607927            -15.611810
# 27      6.711791        14.459845          -0.588209             -7.840155
# 28      6.336207        13.739224          -3.263793            -13.760776
# 29      6.626286        14.996332          -3.373714            -15.803668

# %%
# For testing purposes, calculate the new EV FGA and FGM
# EVFGA
shot_zone_focused_df['EVFGA'] = (shot_zone_focused_df['EV_RA_Attempts'] +
                                 shot_zone_focused_df['EV_NRA_Attempts'] +
                                 shot_zone_focused_df['EV_MR_Attempts'] +
                                 shot_zone_focused_df['EV_LC3_Attempts'] +
                                 shot_zone_focused_df['EV_RC3_Attempts'] +
                                 shot_zone_focused_df['EV_AB3_Attempts'])

# EVFGM
shot_zone_focused_df['EVFGM'] = (shot_zone_focused_df['EV_RA_Makes'] +
                                 shot_zone_focused_df['EV_NRA_Makes'] +
                                 shot_zone_focused_df['EV_MR_Makes'] +
                                 shot_zone_focused_df['EV_LC3_Makes'] +
                                 shot_zone_focused_df['EV_RC3_Makes'] +
                                 shot_zone_focused_df['EV_AB3_Makes'])

# EV_Point_total
shot_zone_focused_df['EV_Point_total'] = ((shot_zone_focused_df['EV_RA_Makes'] * 2) +
                                 (shot_zone_focused_df['EV_NRA_Makes'] * 2) +
                                 (shot_zone_focused_df['EV_MR_Makes'] * 2) +
                                 (shot_zone_focused_df['EV_LC3_Makes'] * 3) +
                                 (shot_zone_focused_df['EV_RC3_Makes'] * 3) +
                                 (shot_zone_focused_df['EV_AB3_Makes'] * 3) )

# EV_Point_total - Total_Points
shot_zone_focused_df['EV_Point_Diff'] = shot_zone_focused_df['EV_Point_total'] - shot_zone_focused_df['Total_Points'] 

shot_zone_focused_df[['Team',
                      'Total_FGA','EVFGA',
                      'Total_FGM','EVFGM',
                      'Total_Points','EV_Point_total',
                      'EV_Point_Diff']]

#Let's go!
# Out:
#                       Team  Total_FGA  EVFGA  Total_FGM  EVFGM  Total_Points  \
# 0            Atlanta Hawks       91.3   91.3       42.8   42.8          98.5
# 1           Boston Celtics       91.5   91.5       41.9   41.9         102.2
# 2            Brooklyn Nets       84.0   84.0       38.1   38.1          90.9
# 3        Charlotte Hornets       89.7   89.7       38.4   38.4          91.3
# 4            Chicago Bulls       91.7   91.7       42.8   42.8         101.9
# 5      Cleveland Cavaliers       88.9   88.9       44.9   44.9         106.1
# 6         Dallas Mavericks       88.5   88.5       42.9   42.9          99.3
# 7           Denver Nuggets       89.2   89.2       45.1   45.1         102.0
# 8          Detroit Pistons       88.7   88.7       41.5   41.5          96.5
# 9    Golden State Warriors       91.9   91.9       41.2   41.2          97.4
# 10         Houston Rockets       93.7   93.7       41.5   41.5          94.9
# 11          Indiana Pacers       87.3   87.3       42.7   42.7          98.1
# 12             LA Clippers       85.6   85.6       40.0   40.0          92.6
# 13      Los Angeles Lakers       85.4   85.4       40.5   40.5          92.7
# 14       Memphis Grizzlies       93.0   93.0       45.2   45.2         104.5
# 15              Miami Heat       86.6   86.6       39.2   39.2          92.8
# 16         Milwaukee Bucks       85.5   85.5       41.0   41.0          96.5
# 17  Minnesota Timberwolves       85.9   85.9       39.6   39.6          94.2
# 18    New Orleans Pelicans       89.9   89.9       39.6   39.6          90.5
# 19         New York Knicks       87.3   87.3       43.6   43.6         101.2
# 20   Oklahoma City Thunder       92.5   92.5       43.3   43.3         100.2
# 21           Orlando Magic       84.6   84.6       38.2   38.2          87.8
# 22      Philadelphia 76ers       85.5   85.5       37.9   37.9          87.8
# 23            Phoenix Suns       85.2   85.2       40.0   40.0          94.5
# 24  Portland Trail Blazers       89.9   89.9       39.9   39.9          91.9
# 25        Sacramento Kings       89.2   89.2       42.7   42.7          97.3
# 26       San Antonio Spurs       87.2   87.2       39.9   39.9          93.6
# 27         Toronto Raptors       90.7   90.7       42.1   42.1          95.6
# 28               Utah Jazz       85.0   85.0       39.2   39.2          92.2
# 29      Washington Wizards       90.3   90.3       39.9   39.9          92.0
#
#     EV_Point_total  EV_Point_Diff
# 0       108.677053      10.177053
# 1       105.964401       3.764401
# 2        96.036581       5.136581
# 3        97.557280       6.257280
# 4       108.284803       6.384803
# 5       113.908677       7.808677
# 6       108.149569       8.849569
# 7       114.752971      12.752971
# 8       104.461371       7.961371
# 9       105.164254       7.764254
# 10      105.174053      10.274053
# 11      108.534062      10.434062
# 12      101.687192       9.087192
# 13      102.418994       9.718994
# 14      113.620611       9.120611
# 15       99.863118       7.063118
# 16      104.931005       8.431005
# 17      100.164706       5.964706
# 18       99.728608       9.228608
# 19      110.001070       8.801070
# 20      108.226085       8.026085
# 21       95.635461       7.835461
# 22       95.652989       7.852989
# 23      100.974820       6.474820
# 24      101.001699       9.101699
# 25      106.595290       9.295290
# 26      101.120122       7.520122
# 27      106.579438      10.979438
# 28       99.943103       7.743103
# 29      100.430922       8.430922

# %%
# Calculate the expected value of a shot
shot_zone_focused_df['Shot_EV'] = (
    ((shot_zone_focused_df['EV_RA']) * shot_zone_focused_df['RA_PA']) +
    ((shot_zone_focused_df['EV_NRA']) * shot_zone_focused_df['NRA_PA']) +
    ((shot_zone_focused_df['EV_MR']) * shot_zone_focused_df['MR_PA']) +
    ((shot_zone_focused_df['EV_LC3']) * shot_zone_focused_df['LC3_PA']) +
    ((shot_zone_focused_df['EV_RC3']) * shot_zone_focused_df['RC3_PA']) +
    ((shot_zone_focused_df['EV_AB3']) * shot_zone_focused_df['AB3_PA'])
)

shot_zone_focused_df[['Team','Shot_EV']]
# Out:
#                       Team   Shot_EV
# 0            Atlanta Hawks  1.078309
# 1           Boston Celtics  1.119183
# 2            Brooklyn Nets  1.079277
# 3        Charlotte Hornets  1.016685
# 4            Chicago Bulls  1.113338
# 5      Cleveland Cavaliers  1.195897
# 6         Dallas Mavericks  1.122067
# 7           Denver Nuggets  1.137929
# 8          Detroit Pistons  1.086670
# 9    Golden State Warriors  1.058986
# 10         Houston Rockets  1.014507
# 11          Indiana Pacers  1.125582
# 12             LA Clippers  1.084397
# 13      Los Angeles Lakers  1.088331
# 14       Memphis Grizzlies  1.121645
# 15              Miami Heat  1.073238
# 16         Milwaukee Bucks  1.126258
# 17  Minnesota Timberwolves  1.091490
# 18    New Orleans Pelicans  1.006315
# 19         New York Knicks  1.158622
# 20   Oklahoma City Thunder  1.076865
# 21           Orlando Magic  1.035785
# 22      Philadelphia 76ers  1.030496
# 23            Phoenix Suns  1.105839
# 24  Portland Trail Blazers  1.021730
# 25        Sacramento Kings  1.089467
# 26       San Antonio Spurs  1.070606
# 27         Toronto Raptors  1.055246
# 28               Utah Jazz  1.086414
# 29      Washington Wizards  1.020599

# %%
# Setting up visualization area
#!pip3 install matplotlib seaborn plotly pandas

import matplotlib.pyplot as plt
import seaborn
import plotly
import pandas

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
# Create the bar chart
plt.figure(figsize=(12, 6))  # Adjust figure size to make room for labels
plt.bar(shot_zone_focused_df['Team'], shot_zone_focused_df['EV_Point_total'], color='blue')

# Add a title and axis labels
plt.title("Team EV Totals", fontsize=16)
plt.xlabel("Teams", fontsize=14)
plt.ylabel("EV Total", fontsize=14)

# Rotate x-axis labels and align them
plt.xticks(rotation=45, ha='right', fontsize=12)  # Rotate labels, align them to the right

# Add grid lines for readability (optional)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adjust layout to prevent clipping
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Example: Color coding based on performance threshold
threshold = shot_zone_focused_df['EV_Point_Diff'].median()
colors = ['red' if ev > threshold else 'green' for ev in shot_zone_focused_df['EV_Point_Diff']]

# Set up the figure
plt.figure(figsize=(15, 6))  # Adjust the size of the figure
bars = plt.bar(shot_zone_focused_df['Team'], shot_zone_focused_df['EV_Point_Diff'], color=colors)

# Title and labels
plt.title("Team EV Point Diff (Color-Coded by Performance)", fontsize=16, weight='bold')
plt.xlabel("Teams", fontsize=14, labelpad=10)  # Labelpad adjusts spacing
plt.ylabel("EV Point Diff", fontsize=14, labelpad=10)

# Rotate x-axis labels
plt.xticks(rotation=45, ha='right', fontsize=12)

# Add data labels
for bar in bars:
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 1,  # Position above the bar
             f'{bar.get_height():.1f}', ha='center', va='bottom', fontsize=10)

# Add a horizontal grid for clarity
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Add a legend for color coding
from matplotlib.patches import Patch
legend_elements = [
    Patch(facecolor='green', label=f'Below Threshold ({threshold})'),
    Patch(facecolor='red', label=f'Above Threshold ({threshold})')
]
plt.legend(handles=legend_elements, loc='upper left', fontsize=12)

# Tight layout to avoid clipping
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# What can we takeaway from 'Team EV Point Diff (Color-Coded by Performance':
# - The green means that these teams are performing somewhat close to their optimal performance. For example, the Boston Celtics are performing only 3.1 points away from their optimal performance. This means they are already getting the most out of the shots they are taking. This aligns with what we know about the Celtics in practice, as they are a heavily analytics-based team that shoots a lot of threes and takes shots in the paint. They also are the defending champions. This is important to note that the defending champion is already heavily using analytics. We could surmise that the 2025 NBA champion is likely to to performing somewhat optimal to their EV maximum.

# %%
# # 1. Bar Chart with Actual vs. Expected

# import numpy as np

# # Example data
# teams = shot_zone_focused_df['Team']
# actual_attempts = shot_zone_focused_df['NRA_FGA']
# ev_attemtps = shot_zone_focused_df['EV_NRA_Attempts']

# x = np.arange(len(teams))  # x positions for the teams
# width = 0.35  # Width of the bars

# plt.figure(figsize=(12, 6))
# plt.bar(x - width/2, actual_makes, width, label='Actual Attempts', color='blue')
# plt.bar(x + width/2, expected_makes, width, label='EV Attempts', color='orange')

# # Add labels and title
# plt.title("Actual vs. EV Attempts per Game", fontsize=16)
# plt.xlabel("Teams", fontsize=14)
# plt.ylabel("Attempts", fontsize=14)
# plt.xticks(x, teams, rotation=45, ha='right')
# plt.legend(fontsize=12)
# plt.tight_layout()
# plt.show()

# %%
# 2. Scatter Plot: Correlation Between Actual and Expected
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.scatter(shot_zone_focused_df['NRA_FGA'], shot_zone_focused_df['EV_NRA_Attempts'], color='purple', alpha=0.7)
plt.title("Correlation Between Actual and EV Attempts", fontsize=16)
plt.xlabel("Actual Attempts", fontsize=14)
plt.ylabel("EV Attempts", fontsize=14)

# Add a 1:1 line
plt.plot([0, max(shot_zone_focused_df['NRA_FGA'])], [0, max(shot_zone_focused_df['EV_NRA_Attempts'])], linestyle='--', color='red', label="1:1 Line")
plt.legend()
plt.show()

# %%
# 3. Deviation Plot (Difference Between Actual and Expected)

deviation = shot_zone_focused_df['NRA_FGA'] - shot_zone_focused_df['EV_NRA_Attempts']

plt.figure(figsize=(12, 6))
bars = plt.bar(teams, deviation, color=['red' if dev > 0 else 'green' for dev in deviation])
plt.title("Deviation: Actual vs. EV NRA Attempts", fontsize=16)
plt.axhline(0, color='black', linewidth=1)  # Add a baseline
plt.xlabel("Teams", fontsize=14)
plt.ylabel("Deviation (NRA Attempts)", fontsize=14)
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# What we can take away:
# - The Bulls and Cavs actually need to take a little more NRA, while the rest of the league needs to take significantly less

# %%
# # 4. Stacked Bar Chart for Makes and Misses
# teams = shot_zone_focused_df['Team']
# actual_misses = shot_zone_focused_df['NRA_FGA'] - shot_zone_focused_df['NRA_FGM']
# ev_misses = shot_zone_focused_df['EV_NRA_Attempts'] - shot_zone_focused_df['EV_NRA_Makes']

# x = np.arange(len(teams))  # x positions for the teams

# plt.figure(figsize=(12, 6))
# plt.bar(x, shot_zone_focused_df['NRA_FGM'], label='Actual Makes', color='blue')
# plt.bar(x, actual_misses, bottom=actual_makes, label='Actual Misses', color='red')
# plt.bar(x, shot_zone_focused_df['EV_NRA_Makes'], label='Expected Makes', color='orange', alpha=0.5)
# plt.bar(x, ev_misses, bottom=shot_zone_focused_df['EV_NRA_Makes'], label='Expected Misses', color='gray', alpha=0.5)

# plt.title("Makes and Misses (Actual vs. Expected)", fontsize=16)
# plt.xlabel("Teams", fontsize=14)
# plt.ylabel("Shots", fontsize=14)
# plt.xticks(x, teams, rotation=45, ha='right')
# plt.legend(fontsize=12)
# plt.tight_layout()
# plt.show()

# %%
# 5. Heatmap
import seaborn as sns
import matplotlib.pyplot as plt

# Heatmap for NRA
# Set the figure size
plt.figure(figsize=(20, 4))  # Adjust the size as needed

# Create the heatmap
data = shot_zone_focused_df[['NRA_FGA', 'EV_NRA_Attempts']]
sns.heatmap(data.T, annot=True, fmt=".1f", cmap="coolwarm", xticklabels=shot_zone_focused_df['Team'])

# Title and show plot
plt.title("Heatmap of Actual and Expected NRA Performance", fontsize=16)

# Save the plot as an image file
plt.savefig("heatmap_actual_expected_nra_performance.png", dpi=300, bbox_inches='tight')  # You can change the file format and name

# Show the plot
plt.show()

# %% [markdown]
# What can we learn from "Heatmap of Actual and Expected Performance":
# - All NBA teams need to take significanlty less NRAs
# - Teams that have both tiles matching in color shades mean they are matching their optimal performance
# - *This is probably the most informative chart we have created*

# %%
# 5. Heatmap
import seaborn as sns
import matplotlib.pyplot as plt

# Heatmap for LC3
# Set the figure size
plt.figure(figsize=(20, 4))  # Adjust the size as needed

# Create the heatmap
data = shot_zone_focused_df[['LC3_FGA', 'EV_LC3_Attempts']]
sns.heatmap(data.T, annot=True, fmt=".1f", cmap="coolwarm", xticklabels=shot_zone_focused_df['Team'])

# Title and show plot
plt.title("Heatmap of Actual and Expected LC3 Performance", fontsize=16)

# Save the plot as an image file
plt.savefig("heatmap_actual_expected_lc3_performance.png", dpi=300, bbox_inches='tight')  # You can change the file format and name

# Show the plot
plt.show()

# %%
# # 6. Line Chart: Trend Over Time (if you have time-series data)
# plt.figure(figsize=(12, 6))
# plt.plot(shot_data['Game_Number'], shot_data['Actual_Makes'], label='Actual Makes', color='blue')
# plt.plot(shot_data['Game_Number'], shot_data['Expected_Makes'], label='Expected Makes', color='orange', linestyle='--')

# plt.title("Actual vs. Expected Makes Over Games", fontsize=16)
# plt.xlabel("Game Number", fontsize=14)
# plt.ylabel("Makes", fontsize=14)
# plt.legend(fontsize=12)
# plt.grid(alpha=0.5)
# plt.tight_layout()
# plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Example data (replace with your actual data)
teams = shot_zone_focused_df['Team']
total_points = shot_zone_focused_df['Total_Points']  # Replace with actual points scored data
ev_points = shot_zone_focused_df['EV_Point_total']  # Replace with expected points data

x = np.arange(len(teams))  # x positions for the teams
width = 0.35  # Width of the bars

plt.figure(figsize=(20, 10))
plt.bar(x - width / 2, total_points, width, label='Total Points', color='blue')
plt.bar(x + width / 2, ev_points, width, label='EV Points', color='orange')

plt.title("Actual vs. EV Total Points per Game", fontsize=16)
plt.xlabel("Teams", fontsize=14)
plt.ylabel("Points", fontsize=14)
plt.xticks(x, teams, rotation=45, ha='right')
plt.legend(fontsize=12)
plt.tight_layout()
plt.show()
